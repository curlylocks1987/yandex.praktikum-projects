# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Банки---анализ-оттока-клиентов" data-toc-modified-id="Банки---анализ-оттока-клиентов-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Банки - анализ оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Задача" data-toc-modified-id="Задача-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Задача</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Ссылки-на-доп.-материалы" data-toc-modified-id="Ссылки-на-доп.-материалы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Ссылки на доп. материалы</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-загрузке-данных" data-toc-modified-id="Вывод-по-загрузке-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод по загрузке данных</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названий-столбцов" data-toc-modified-id="Замена-названий-столбцов-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Замена названий столбцов</a></span></li><li><span><a href="#Словарь-русских-названий-столбцов" data-toc-modified-id="Словарь-русских-названий-столбцов-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Словарь русских названий столбцов</a></span></li><li><span><a href="#Пропуски-в-столбце-Balance" data-toc-modified-id="Пропуски-в-столбце-Balance-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Пропуски в столбце <code>Balance</code></a></span></li><li><span><a href="#Вывод-по-предобработке" data-toc-modified-id="Вывод-по-предобработке-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Вывод по предобработке</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Средние-и-стандартные-отклонения-признаков" data-toc-modified-id="Средние-и-стандартные-отклонения-признаков-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Средние и стандартные отклонения признаков</a></span></li><li><span><a href="#Распределения-признаков" data-toc-modified-id="Распределения-признаков-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Распределения признаков</a></span><ul class="toc-item"><li><span><a href="#Количественные-признаки" data-toc-modified-id="Количественные-признаки-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Количественные признаки</a></span></li><li><span><a href="#Категоральные-и-дискретные-признаки" data-toc-modified-id="Категоральные-и-дискретные-признаки-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Категоральные и дискретные признаки</a></span></li></ul></li><li><span><a href="#Корреляции" data-toc-modified-id="Корреляции-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Корреляции</a></span></li><li><span><a href="#Вывод-по-EDA" data-toc-modified-id="Вывод-по-EDA-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Вывод по EDA</a></span></li></ul></li><li><span><a href="#Портреты-клиентов-склонных-к-оттоку" data-toc-modified-id="Портреты-клиентов-склонных-к-оттоку-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Портреты клиентов склонных к оттоку</a></span><ul class="toc-item"><li><span><a href="#Средние-по-группам-оттока" data-toc-modified-id="Средние-по-группам-оттока-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Средние по группам оттока</a></span></li><li><span><a href="#Распределение-признаков-по-группам-оттока" data-toc-modified-id="Распределение-признаков-по-группам-оттока-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Распределение признаков по группам оттока</a></span><ul class="toc-item"><li><span><a href="#Количественные" data-toc-modified-id="Количественные-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Количественные</a></span></li><li><span><a href="#Категоральные-и-дискретные" data-toc-modified-id="Категоральные-и-дискретные-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Категоральные и дискретные</a></span></li></ul></li><li><span><a href="#Вывод-по-портретам-клиентов" data-toc-modified-id="Вывод-по-портретам-клиентов-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Вывод по портретам клиентов</a></span></li></ul></li><li><span><a href="#Проверка-гипотезы-о-различии-дохода-клиентов,-которые-остались-и-которые-ушли-в-отток." data-toc-modified-id="Проверка-гипотезы-о-различии-дохода-клиентов,-которые-остались-и-которые-ушли-в-отток.-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Проверка гипотезы о различии дохода клиентов, которые остались и которые ушли в отток.</a></span></li><li><span><a href="#Гипотеза-о-различии-доли-оттока-среди-лояльных-и-нелояльных-клиентов" data-toc-modified-id="Гипотеза-о-различии-доли-оттока-среди-лояльных-и-нелояльных-клиентов-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Гипотеза о различии доли оттока среди лояльных и нелояльных клиентов</a></span></li><li><span><a href="#Итоги" data-toc-modified-id="Итоги-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Итоги</a></span><ul class="toc-item"><li><span><a href="#Основные-этапы" data-toc-modified-id="Основные-этапы-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Основные этапы</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import numpy as np
import warnings
import scipy.stats as st
import math as mth
warnings.filterwarnings("ignore")

# %% [markdown]
# # Банки - анализ оттока клиентов

# %% [markdown]
# ## Задача
#
# Проанализировать клиентов регионального банка и выделить портрет клиентов, которые склонны уходить из банка.
#
# - Провести исследовательский анализ данных,
# - Выделить портреты клиентов, которые склонны уходить из банка,
# - Сформулировать и проверить статистические гипотезы.
#
#     *Гипотезу различия дохода между теми клиентами, которые ушли и теми, которые остались.*
#
#     *Статистическую гипотезу относительно представленных данных*

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Датасет содержит данные о клиентах банка «Метанпром». Банк располагается в Ярославле и областных городах: Ростов Великий и Рыбинск.
#
# Колонки:
#
# - `userid` — идентификатор пользователя,
# - `score` — баллы кредитного скоринга,
# - `City` — город,
# - `Gender` — пол,
# - `Age` — возраст,
# - `Objects` — количество объектов в собственности,
# - `Balance` — баланс на счёте,
# - `Products` — количество продуктов, которыми пользуется клиент,
# - `CreditCard` — есть ли кредитная карта,
# - `Loyalty` — активный клиент,
# - `estimated_salary` — заработная плата клиента,
# - `Churn` — ушёл или нет.

# %% [markdown]
# # Ссылки на доп. материалы

# %% [markdown]
# [Презентация](https://yadi.sk/i/AgOB9UZf5vE2pg) в pdf на Яндекс.Диск
#
# [Дашборд](https://public.tableau.com/views/Metanprom_Churn/Dashboard1?:language=en&:display_count=y&publish=yes&:origin=viz_share_link) в Tableau Public

# %% [markdown]
# # Загрузка данных

# %%
df = pd.read_csv('datasets/bank_dataset.csv')
df
# Out:
#         userid  score            City Gender  Age  Objects    Balance  \
# 0     15677338    619       Ярославль      Ж   42        2        NaN
# 1     15690047    608         Рыбинск      Ж   41        1   83807.86
# 2     15662040    502       Ярославль      Ж   42        8  159660.80
# 3     15744090    699       Ярославль      Ж   39        1        NaN
# 4     15780624    850         Рыбинск      Ж   43        2  125510.82
# ...        ...    ...             ...    ...  ...      ...        ...
# 9995  15648965    771       Ярославль      М   39        5        NaN
# 9996  15612628    516       Ярославль      М   35       10   57369.61
# 9997  15627268    709       Ярославль      Ж   36        7        NaN
# 9998  15725091    772  Ростов Великий      М   42        3   75075.31
# 9999  15671055    792       Ярославль      Ж   28        4  130142.79
#
#       Products  CreditCard  Loyalty  estimated_salary  Churn
# 0            1           1        1         101348.88      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# userid              10000 non-null int64
# score               10000 non-null int64
# City                10000 non-null object
# Gender              10000 non-null object
# Age                 10000 non-null int64
# Objects             10000 non-null int64
# Balance             6383 non-null float64
# Products            10000 non-null int64
# CreditCard          10000 non-null int64
# Loyalty             10000 non-null int64
# estimated_salary    10000 non-null float64
# Churn               10000 non-null int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# Определим процент пропущенных значений в столбце `Balance`:

# %%
df['Balance'].isna().sum()/len(df)
# Out:
# 0.3617

# %% [markdown]
# Посмотрим на дубликаты, предварительно удалив столбец `userid`:

# %%
df.drop('userid', axis=1).duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Вывод по загрузке данных

# %% [markdown]
# - 10000 строк, 12 столбцов
# - Пропущенные значения (около 36%) есть в столбце `Balance`.
# - Дубликаты не обнаружены
# - Типы данных корректные, соответсвуют значениям столбцов.
#
# Для этапа предобработки данных получаем следующие задания:
#
# - Заменить названия столбцов на строчные буквы, разделив слова нижним подчеркиванием
# - Сделать словарь с русскими названиями столбцов, для дальнейшего отображения на графиках.
# - Заменить "M/Ж" на "1/0" в столбце пол.
# - Понять, что делать с пропусками в столбце `Balance`, т.е. остаток на счете. 36% игнорировать точно не получится, удалять такое количество данных немыслимо.

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Замена названий столбцов

# %%
df.columns = [col.lower() for col in df.columns]
df = df.rename(columns = {'userid':'user_id','creditcard':'credit_card'})
df.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'credit_card', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %% [markdown]
# ## Словарь русских названий столбцов

# %%
rus_columns = ['id пользователя', 'кредитный скоринг', 'город', 'пол', 'возраст', 'объекты в собственности',
              'остаток на счете', 'используемые продукты', 'кредитная карта', 'лояльность', 'оценка зарплаты',
              'отток']
df_columns_dict = dict(zip(df.columns, rus_columns))
df_columns_dict
# Out:
# {'user_id': 'id пользователя',
#  'score': 'кредитный скоринг',
#  'city': 'город',
#  'gender': 'пол',
#  'age': 'возраст',
#  'objects': 'объекты в собственности',
#  'balance': 'остаток на счете',
#  'products': 'используемые продукты',
#  'credit_card': 'кредитная карта',
#  'loyalty': 'лояльность',
#  'estimated_salary': 'оценка зарплаты',
#  'churn': 'отток'}

# %% [markdown]
# ## Пропуски в столбце `Balance`

# %%
df[df['balance'].isna()]['balance'].unique()
# Out:
# array([nan])

# %% [markdown]
# Все пропуски - это `NaN`'ы

# %%
df['balance'].describe()
# Out:
# count      6383.000000
# mean     119827.493793
# std       30095.056462
# min        3768.690000
# 25%      100181.975000
# 50%      119839.690000
# 75%      139512.290000
# max      250898.090000
# Name: balance, dtype: float64

# %%
df['balance'].hist()
plt.title("Гистограмма распределения остатков на счете")
plt.show()

# %% [markdown]
# Видим, что минимальное значение остатка в непропущенных данных равно 3768.69, т.е. у нас совсем не представленны балансы близкие к нулю. Это странно, если предположить, что речь идет об остатке на счете в конце периода, но более логично, если речь идет о некотором среднем за период.
#
# В целом распределение почти идеально нормальное.

# %% [markdown]
# Поскольку мы исследуем отток, интересно посмотреть как пропуски распределены при группировке по оттоку.

# %%
df.groupby('churn')['balance'].apply(lambda x: x.isna().sum())
# Out:
# churn
# 0    3117
# 1     500
# Name: balance, dtype: int64

# %%
df['churn'].mean()
# Out:
# 0.2037

# %% [markdown]
# Получается, что __пропуски в основном (соотношение 6:1) приходятся на тех, кто остался клиентом__. Соотношение оставшихся и ушедших клиентов при этом 5:1. Не слишком существенно.
#
# Посмотрим, верно ли, что в основном пропуски связанны с тем, что клиент пользуется кредитной картой:

# %%
df.groupby('credit_card')['balance'].apply(lambda x: x.isna().sum())
# Out:
# credit_card
# 0    1025
# 1    2592
# Name: balance, dtype: int64

# %%
df['credit_card'].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: credit_card, dtype: int64

# %% [markdown]
# Пропуски в __2,5 раза чаще встречаются для клиентов с кредитной картой__, при том, что общее соотношение 3:7. Не похоже на существенную разницу.
#
# Посмотрим на количество продуктов.

# %%
df.groupby('products')['balance'].apply(lambda x: x.isna().sum())
# Out:
# products
# 1     905
# 2    2600
# 3      98
# 4      14
# Name: balance, dtype: int64

# %%
df['products'].value_counts()
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: products, dtype: int64

# %% [markdown]
# Видим, __большинство пропусков для клиентов, пользующихся 2 продуктами__. Тогда, как в целом соотношение пользующихся 1 и 2 продуктами примерно равное. Похоже на некую существенную тенденцию.

# %% [markdown]
# Это значит, что скорее всего всего все __пропущенные значения означают нулевой баланс или по крайней мере меньший, чем 3768.69__. Не возможно представить себе ситуацию, чтобы банк не имел данных об остатке денег на счету клиента.
#
# Другой вариант, что речь идет о __клиентах, использующих только кредитные продукты и не держащих собственных средств на дебетовом счете__. В таком случае у клиента как раз могут быть два продукта: например, ипотека и кредитка.
#
# В любом случае, без уточняющей информации мы не можем заполнять или удалять эти пропуски.

# %% [markdown]
# ## Вывод по предобработке

# %% [markdown]
#  - Проанализировали пропуски в столбце `Balance`. Поскольку точно не известно назначение данного столбца (среднее за период или остаток на заданную дату), мы не можем определить и природу пропусков. Установили, что чаще всего пропуски возникают для клиентов, использующих ровно 2 продукта. Также заметили, что заполненные значения не бывают меньше 3768.69. Две гипотезы: __либо пропуски означают низкие остатки__, или речь идет о __клиентах без дебетового счета__. Удалять или заменять пропуски пока нецелесообразно.
#
# - Заменили названия столбцов на более удобные и создали словарь русских названий для дальнейшего пользования.

# %% [markdown]
# # EDA

# %%
df_no_id = df.drop('user_id', axis=1)

# %% [markdown]
# В этом разделе мы посмотрим на наши данные в общем, не фокусируясь пока на группировке по факту оттока. Главная цель в принципе узнать с какими данными мы работаем, увидеть возможные аномалии.

# %% [markdown]
# ## Средние и стандартные отклонения признаков

# %%
gender_dict = {'Ж':0,'М':1}
mean_std = df_no_id.replace({'gender':gender_dict}).agg(['mean', 'std']).T.round(2)
mean_std
# Out:
#                        mean       std
# score                650.53     96.65
# gender                 0.55      0.50
# age                   38.92     10.49
# objects                5.01      2.89
# balance           119827.49  30095.06
# products               1.53      0.58
# credit_card            0.71      0.46
# loyalty                0.52      0.50
# estimated_salary  100090.24  57510.49
# churn                  0.20      0.40

# %% [markdown]
# Сами по себе средние и стандартные отклонения позволяют наметить шкалу реферанса для будущих выводов. Можно заметить, что средний отток в выборке равен 20%.

# %% [markdown]
# ## Распределения признаков

# %% [markdown]
# ### Количественные признаки

# %%
df_quant = df_no_id[['score', 'age', 'balance', 'estimated_salary']]
with sns.axes_style('darkgrid'):
    for col in df_quant.columns:
        A = df[col]
        A_no_nan = A[~np.isnan(A)]
    
        sns.distplot(A_no_nan, kde=False, bins=30)
        plt.title(f'Распределение признака "{df_columns_dict[col]}"')
        plt.xlabel(df_columns_dict[col])
        plt.ylabel('Количество клиентов')
        plt.show()

# %% [markdown]
# В целом хорошие распределения количественных признаков.
#
# Из аномалий, видим, всплеск распределения кредитного скоринга на значениях выше 830 (при максимуме 850). Скорее всего это говорит о том, что модель скоринга искусственно обрезана на значении 850, т.е. многие клиенты могли бы получить и больше, но это по каким-то причинам не целесообразно. Хвост распределения превратился во всплеск.
#
# Также интересно заметить, что зарплаты клиентов распределены однородно. Это несколько странно, скорее ожидаешь увидеть скошенную нормальную кривую. Но тут вспомнаем, что речь идет об оценках, т.е. о некой модели. Интересна также природа выборки, может быть специально отбирали равные группы по зарплате?

# %% [markdown]
# ### Категоральные и дискретные признаки

# %%
df_cat = df_no_id[['city', 'gender', 'objects', 'products', 'credit_card', 'loyalty', 'churn']]
with sns.axes_style('whitegrid'):
    for col in df_cat.columns:
        sns.catplot(x=col, kind='count', palette="ch:.25", data=df)
        plt.title(f'Распределение признака "{df_columns_dict[col]}"')
        plt.xlabel('')
        plt.ylabel('Количество клиентов')
        plt.grid(True, axis='y', linestyle='--')
        plt.show()

# %% [markdown]
# По категоральным и дискретным признакам с небольшим количеством значений можно заметить следующее:
#
# - Ожидаемо, большинство людей из областного центра Ярославля. Рыбинск и Ростов примерно поровну.
# - Соотношение полов 55:45 в пользу мужчин.
# - По количеству объектов собственности распределение почти однородное с хвостами в 0 и 10, т.е. одинаковое количество человек (примерно по 1000) в выборке владеет одним, двумя, тремя, ..., девятью объектами. Только тех у кого 0 или 10 объектов собственности меньше (около 400). Не совсем ясна природа такой однородности. Может быть дело в специальной выборке?
# - Подавляющее большинство клиентов в выборке пользуются 1 или 2 продуктами. Между этими группами почти нет разницы в размере.
# - Кредитками пользуются 71% клиентов.
# - Отток 20%, лояльность 52%.

# %% [markdown]
# ## Корреляции

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df_no_id.corr(), annot=True)
plt.title('Матрица линейной корреляции')
plt.show()

# %% [markdown]
# Все абсолютные значения коеффициентов попарной корреляции не превышают 0.3. Это говорит о слабой линейной корреляции между параметрами. Можно отметить некоторую линейную корреляцию оттока и возраста, оттока и лояльности, а также количества продуктов и баланса на счете.
#
# Тут правда нужно заметить, что большинство признаков далеки от нормального распределения, для которого коеффициент Пирсона идеален.

# %% [markdown]
# ## Вывод по EDA

# %% [markdown]
# В ходе EDA посмотрели на данные в целом, посчитали средние и стандартные отклонения, построили распределения и матрицу корреляции.
#
# Общий анализ данных в целом не выявил каких-то аномалий. Можно отметить лишь странную однородность распределения оценочного дохода и количества объектов в собственности. Возможно они обусловлены особенностями формирования выборки.
#
# Также можно отметить скачок на максимальном кредитном скоринге, видимо обусловленный моделью скоринга.

# %% [markdown]
# # Портреты клиентов склонных к оттоку

# %% [markdown]
# ## Средние по группам оттока

# %%
mean_churn = df_no_id.replace({'gender':gender_dict}).groupby('churn').agg('mean').round(2).T
mean_churn_overall = mean_churn.join(mean_std)
mean_churn_overall = mean_churn_overall.rename(columns = {0:'mean_stay', 1:'mean_churn', 'mean':'overall_mean'})
mean_churn_overall
# Out:
#                   mean_stay  mean_churn  overall_mean       std
# score                651.85      645.35        650.53     96.65
# gender                 0.57        0.44          0.55      0.50
# age                   37.41       44.84         38.92     10.49
# objects                5.03        4.93          5.01      2.89
# balance           119535.86   120746.97     119827.49  30095.06
# products               1.54        1.48          1.53      0.58
# credit_card            0.71        0.70          0.71      0.46
# loyalty                0.55        0.36          0.52      0.50
# estimated_salary   99738.39   101465.68     100090.24  57510.49

# %% [markdown]
# Уже видим какой-то водораздел по возрасту, полу и лояльности. Разница в остальных параметрах, учитывая стандартные отклонения скорее в рамках статистической погрешности.
#
# Можно нормировать все признаки по формуле $$\frac{x-\bar{x}}{s},$$ где $\bar{x}$ - среднее выборки, $s$ - стандартное отклонение выборки.

# %%
mean_churn_norm = pd.DataFrame()
mean_churn_norm['mean_stay'] = (mean_churn_overall['mean_stay'] - mean_churn_overall['overall_mean'])/mean_churn_overall['std']
mean_churn_norm['mean_churn'] = (mean_churn_overall['mean_churn'] - mean_churn_overall['overall_mean'])/mean_churn_overall['std']
mean_churn_norm = mean_churn_norm[['mean_stay', 'mean_churn']]
mean_churn_norm['difference'] = abs(mean_churn_norm['mean_stay'] - mean_churn_norm['mean_churn'])
mean_churn_norm.round(2)
# Out:
#                   mean_stay  mean_churn  difference
# score                  0.01       -0.05        0.07
# gender                 0.04       -0.22        0.26
# age                   -0.14        0.56        0.71
# objects                0.01       -0.03        0.03
# balance               -0.01        0.03        0.04
# products               0.02       -0.09        0.10
# credit_card            0.00       -0.02        0.02
# loyalty                0.06       -0.32        0.38
# estimated_salary      -0.01        0.02        0.03

# %% [markdown]
# Так виднее существенность разницы между группами "ушел" и "остался": __возраст, пол, лояльность__, может быть __количество продуктов__.

# %% [markdown]
# ## Распределение признаков по группам оттока

# %%
df_churn = df.query('churn == 1')
df_no_churn = df.query('churn == 0')

# %% [markdown]
# ### Количественные

# %%
def reformat_large_tick_values(tick_val, pos):
    """
    Turns large tick values (in the billions, millions and thousands) such as 4500 
    into 4.5K and also appropriately turns 4000 into 4K (no zero after the decimal).
    """
    if tick_val >= 1000000000:
        val = round(tick_val/1000000000, 1)
        new_tick_format = '{:}B'.format(val)
    elif tick_val >= 1000000:
        val = round(tick_val/1000000, 1)
        new_tick_format = '{:}M'.format(val)
    elif tick_val >= 1000:
        val = round(tick_val/1000, 1)
        new_tick_format = '{:}K'.format(val)
    elif tick_val < 1000:
        new_tick_format = round(tick_val, 1)
    else:
        new_tick_format = tick_val

    # make new_tick_format into a string value
    new_tick_format = str(new_tick_format)
    
    # code below will keep 4.5M as is but change values such as 4.0M to 4M since that zero after the decimal isn't needed
    index_of_decimal = new_tick_format.find(".")
    
    if index_of_decimal != -1:
        value_after_decimal = new_tick_format[index_of_decimal+1]
        if value_after_decimal == "0":
            # remove the 0 after the decimal point since it's not needed
            new_tick_format = new_tick_format[0:index_of_decimal] + new_tick_format[index_of_decimal+2:]
            
    return new_tick_format

def churn_hist(col):
    '''
    Takes the column name as input, gets rid of nans, 
    then builds two histograms for 'churn' and 'stay' groups on the same axes.
    The ticks are formated in engineering style.
    '''
    A = df_no_churn[col]
    A_no_nan = A[~np.isnan(A)]
    B = df_churn[col]
    B_no_nan = B[~np.isnan(B)]

    sns.distplot(B_no_nan, kde=False, bins=30, norm_hist=True)
    sns.distplot(A_no_nan, kde=False, bins=30, norm_hist=True)
    plt.title(f'Распределение признака "{df_columns_dict[col]}"')
    plt.xlabel(df_columns_dict[col])
    plt.ylabel('Количество клиентов')
    plt.legend(labels = ['ушел', 'остался'])
    plt.grid(axis='y', linestyle='--')
    ax = plt.gca()
    #ax.xaxis.set_major_formatter(ticker.EngFormatter())
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(reformat_large_tick_values))





with sns.axes_style('dark'):
    for col in df_quant.columns:
        churn_hist(col)
        plt.show()

# %% [markdown]
# Видим, что есть довольно __заметные различия по параметру возраст__ в распределении ушедших и оставшихся клиентов. Водоразделом является возраст около 40 лет. После 40 клиенты начинают уходить чаще. Можно высказать гипотезу, что банк позиционирует себя скорее как банк для молодых людей.
#
# Немного чаще уходят люди с остатками на счете от 100 до 150 тыс, а также больше 200 тыс.

# %% [markdown]
# ### Категоральные и дискретные

# %% [markdown]
# Посмотрим на графики и на проценты оттока в каждой категории.

# %%
def cat_bar_stack(col):
    '''
    Function takes column value and builds a stacked bar-chart using pandas.plot with 
    kind='bar'. The stacked groups are 'stay' and 'churn'. The 'churn' bars are labelled
    with percentages.
    '''
    data_all = df[col].value_counts().sort_index()
    data_churn = df_churn[col].value_counts().sort_index()#order the churn data the same way as al
    percentage = (data_churn / data_all).sort_index()
    print(percentage)
    
    bar1 = data_all.plot(kind='bar', color='olive')
    bar2 = data_churn.plot(kind='bar', color='darkred')
    
    #Print percentage of churn in each class
    for i, rect in enumerate(bar2.patches):
        n = int(len(bar2.patches) / 2.0) #We have 2*n patches, but need only the second half.
        if i >= n:
            height = rect.get_height()

            plt.text(rect.get_x() + rect.get_width() / 2.0, height / 4.0, f'{percentage.iloc[int(i-n)]:1.1%}', 
                     ha='center', va='bottom', color='black')

    plt.title(f'Распределение признака "{df_columns_dict[col]}"')
    plt.xlabel('')
    plt.xticks(rotation=360)#strange but it works
    plt.ylabel('Количество клиентов')
    plt.grid(axis='y', linestyle='--')
    plt.legend(['остался', 'ушел'])

    

with sns.axes_style('white'):
    for col in df_cat.drop('churn', axis=1).columns:
        cat_bar_stack(col)
        plt.show()
# Out:
# Ростов Великий    0.324432
# Рыбинск           0.166734
# Ярославль         0.161548
# Name: city, dtype: float64
# Ж    0.250715
# М    0.164559
# Name: gender, dtype: float64
# 0     0.230024
# 1     0.224155
# 2     0.191794
# 3     0.211100
# 4     0.205258
# 5     0.206522
# 6     0.202689
# 7     0.172179
# 8     0.192195
# 9     0.216463
# 10    0.206122
# Name: objects, dtype: float64
# 1    0.277144
# 2    0.075817
# 3    0.827068
# 4    1.000000
# Name: products, dtype: float64
# 0    0.208149
# 1    0.201843
# Name: credit_card, dtype: float64
# 0    0.268509
# 1    0.142691
# Name: loyalty, dtype: float64

# %% [markdown]
# Процент оттока ощутимо выше среднего (20%) мы наблюдаем:
#
# - в Ростове (32.4%)
# - среди женщин (25.1%)
# - среди пользующихся 1 продуктом (27.7%), но особенно для тех у кого 3 (82.7%), 4 продукта (100%)
# - среди нелояльных клиентов (26.9%)
#
# Слегка выше среднего отток для владельцев 0-1 объекта собственности (23 - 22.4%).
#
# Процент оттока ощутимо ниже среднего (20%) мы наблюдаем:
#
# - в Рыбинске и Ярославле (16.7%)
# - для мужчин (16.5%)
# - для людей пользующихся ровно 2 продуктами (7.6%)
# - для лояльных клиентов (14.3%)
#
# Самым интересным тут является пункт с количеством продуктов. Было бы любопытно посмотреть на более подробную статистику по этому вопросу. Ниже видим, что кредиткой клиенты с ровно двумя продуктами или ровно одним пользуются также часто, как и все пользователи в целом. По имеющимся в нашем распоряжении данным трудно сделать даже предположении, о каких продуктах идет речь.

# %%
df.query('products == 2')['credit_card'].value_counts(normalize=True)
# Out:
# 1    0.70719
# 0    0.29281
# Name: credit_card, dtype: float64

# %%
df.query('products == 1')['credit_card'].value_counts(normalize=True)
# Out:
# 1    0.703777
# 0    0.296223
# Name: credit_card, dtype: float64

# %% [markdown]
# ## Вывод по портретам клиентов

# %% [markdown]
# В данном разделе посмотрели на средние признаков в группировке по оттоку, а также построили графики распределения. По итогам исследования можно выделить следующие характерные портреты клиентов.
#
# __Клиент склонен к оттоку__.
# - Проживает в Ростове Великом
# - Женщина
# - Старше 40
# - Использует 1 продукт или же 3, 4 продукта
# - Нелояльна
# - Владеет 0-1 объектом собственности
# - Остаток на счете от 100 до 150 тыс. или больше 200 тыс.
#
# __Клиент склонен остаться__.
# - Проживает в Ярославле или Рыбинске
# - Мужчина
# - Моложе 40
# - Использует ровно 2 продукта
# - Лоялен
# - В собственности больше 1 объекта
# - Остаток от 75 до 100 тыс или от 150 до 200 тыс.
#
# Необходимо заметить, что все указанные признаки могут рассматриваться независимо друг от друга. Последние утверждения об остатке, требуют дополнительной проверки.

# %% [markdown]
# # Проверка гипотезы о различии дохода клиентов, которые остались и которые ушли в отток.

# %%
df['churn'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: churn, dtype: int64

# %%
df.groupby('churn')['estimated_salary'].agg(['mean', 'median', 'std'])
# Out:
#                 mean     median           std
# churn
# 0       99738.391772   99645.04  57405.586966
# 1      101465.677531  102460.84  57912.418071

# %%
churn_hist('estimated_salary')

# %% [markdown]
# Будем проверять нашу гипотезу при помощи __теста Манна-Уитни__, т.к у нас почти одинаковые формы распределения.
#
# Наши формальные гипотезы:
#
# $H_0$: Между группами "ушел" и "остался" нет статистически значимого различия доходов
#
# $H_1$: Между группами есть статистически значимое различие доходов

# %%
ALPHA = .05
def mannwhit (data1, data2, alpha):
    '''
    Для заданных двух групп и ур.знач. alpha проводит тест Манна-Уитни 
    для установления статистического различия между данными
    '''
    print(f'Уровень значимости теста = {alpha}')
    p_v = st.mannwhitneyu(data1, data2).pvalue
    
    print("pvalue = {0:.15f}".format(p_v))
    if (p_v < alpha):
        print('Статистически значимая разница')
    else:
        print('Нет статистически значимой разницы')

mannwhit(df_churn['estimated_salary'], df_no_churn['estimated_salary'], ALPHA)
# Out:
# Уровень значимости теста = 0.05
# pvalue = 0.113525754650769
# Нет статистически значимой разницы

# %% [markdown]
# Видим, что получили довольно высокое p-значение, которое не позволило нам отвергнуть нуль-гипотезу при 5% уровне значимости.
#
# Таким образом, __мы не в праве утверждать, что между группами ушедших и оставшихся клиентов есть статистически значимые различия доходов__.

# %% [markdown]
# # Гипотеза о различии доли оттока среди лояльных и нелояльных клиентов

# %% [markdown]
# Для признака лояльность получили следующее распределение оттока в группах:

# %%
with sns.axes_style('white'):
    cat_bar_stack('loyalty')
# Out:
# 0    0.268509
# 1    0.142691
# Name: loyalty, dtype: float64

# %% [markdown]
# Проверим следующие гипотезы при помощи Z-теста:
#
# $H_0$: доли оттока равны для лояльных и нелояльных клиентов
#
# $H_1$: доли оттока различны для лояльных и нелояльных клиентов

# %%
def test_share_eq(dep_col, ind_col, ALPHA):
    '''
    Функция получает на вход названия колонки зависимого параметра (того чью долю считаем)
    и независимого (того по которому группируем). Оба параметра должны быть булевы. Также
    на вход идет уровень значимости теста, ALPHA.
    
    Расчитывает необходимые доли и проводит Z-test на равенство долей с уровнем значимости ALPHA
    
    Печатает ALPHA, p-value и результат теста.
    '''
    group_size = df[ind_col].value_counts() #размер групп
    share_size = df.groupby(ind_col)[dep_col].sum() #размер целевых подгрупп в группах
   
    
    p = share_size / group_size #доли
    p_combined = share_size.sum() / group_size.sum() #общая доля
    # разница пропорций в датасетах
    difference = p[0] - p[1]
    
    z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/group_size[0] + 1/group_size[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1) 

    p_value = (1 - distr.cdf(abs(z_value))) * 2

    print(f'Уровень значимости: {ALPHA}')
    print('p-значение: {0:.15f}'.format(p_value))

    if (p_value < ALPHA):
        print("Отвергаем нулевую гипотезу: между долями есть значимая разница")
    else:
        print("Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными")

test_share_eq('churn', 'loyalty', .05)
# Out:
# Уровень значимости: 0.05
# p-значение: 0.000000000000000
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %% [markdown]
# Гипотеза о том, что среди лояльных клиентов доля оттока отличается от доли оттока среди нелояльных подтвердилась.
#
# Судя по данным, __среди лояльных клиентов отток меньше__.

# %% [markdown]
# # Итоги

# %% [markdown]
# ## Основные этапы

# %% [markdown]
# Кратко перечислим основные моменты работы:
#
# - Провели предобработку данных: заменили названия столбцов, выявили пропуски типа `NaN` в столбце `balance`. Поскольку их 36% и не совсем ясна их природа, заменять их не стали.
# - В ходе EDA для всех столбцов посмотрели на средние и стандартные отклонения, построили распределения и матрицу линейной корреляции. Выбросы не обнаружили, на лицо странно однородные распределения для заработной платы и количества объектов в собственности.
# - Посмотрев на средние и распределения в группировке по оттоку, построили портреты пользователей, которые ушли, и тех, что остались.
# - Протестировали две статистические гипотезы: о статистически заначимом различии дохода при группировке по оттоку (тест Манна-Уитни) и о равенстве долей оттока при группировке по лояльности (Z-тест).

# %% [markdown]
# ## Выводы

# %% [markdown]
# - Три самых сильных признака оттока:
#     1. Лояльность - 0
#     2. Возраст - старше 40
#     3. Пол - женский
#
# - Отток в Ростове Великом (32%) оказался почти вдвое выше, чем в Ярославле и Рыбинске (16-17%).
# - К оттоку оказались наиболее склонны нелояльные женщины старше 40, проживающие в Ростове Великом, пользующиеся одним или тремя-четырьмя продуктами банка, владеющие 0-1 объектом собственности, зарабатывающие от 100 до 150 тыс. или более 200 тыс.
# - Наоборот, чаще всего остаются с банком лояльные мужчины моложе 40, проживающие в Ярославле и Рыбинске, пользующиеся ровно двумя продуктами банка, владеющие двумя и более объектами собственности, зарабатывающие от 75 до 100 тыс. или от 150 до 200 тыс.
# - Гипотеза о статистически значимом различии дохода клиентов, которые ушли, и тех, которые остались, не подтвердилась.
# - Гипотеза о различии доли тех, кто ушел в отток, среди лояльных и нелояльных клиентов подтвердилась. Лояльные клиенты реже уходят.

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# - Стоит подробно исследовать филиал в Ростове Великом. Почему там отток существенно выше, чем в Рыбинске или Ярославле?
# - В целом стоит работать над увеличением лояльности пользователей.
# - Приоритезировать работу с населением до 40 лет. С другой стороны, исследовать причины увеличения оттока среди старшего населения и принять адекватные меры.
# - Приоритезировать привлечение клиентов мужчин.
# - Разработать комплекс мер для увеличения лояльности женского населения, понять, чем их можно удержать, что их не устраивает.
# - Очень интересно детально исследовать выявленную связь количества используемых банковских продуктов и оттока. Хочется понять природу этой связи, есть ли предпочтение по продуктам у тех, кто уходит и тех кто остается и т.д. Это поможет банку эффективнее выстраивать маркетинговую политику.
# - Посмотреть на модель оценки заработной платы, понять почему получается однородное распределение. То же самое касается количества объектов в собственности. Проверить методы сбора информации и формирования выборки.
